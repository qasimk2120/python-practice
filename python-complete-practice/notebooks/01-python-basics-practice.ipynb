# %% [markdown]
# # Python Basics Practice
#
# ## Overview
#
# This notebook covers fundamental Python concepts required for writing and understanding basic programs.
# It serves as a foundation for later topics such as data structures, control flow, and functions.
#
# ---
#
# ## Concepts Covered
#
# - Variables and basic data types
# - Printing output
# - Simple expressions and operations
# - Basic program structure
#
# ---
#
# ## Purpose
#
# This notebook is intended as an entry point for Python practice and syntax familiarity.

# %%
# Define a string variable with proper naming and type hints
name: str = "George"

# %%
y = 10
print(f"{y} Dollars")

# %%
#Line Continuation
2.0 * 1.5 + \
5

# %%
"Friday"[3]

# %%
def wage (w_hours):
    return w_hours * 25
def with_bonus(w_hours):
    return wage(w_hours) + 50

wage(8), with_bonus(8)

# %%
def add_10(m):
    if m >= 100:
        m = m +10
        return m
    else:
        return "Save more!"
add_10(50)

# %%
Particpants = ['jOHN', 'Leila', 'Gregory', 'Cate']
Particpants
print(Particpants[-1])

# %%
del Particpants[2]

# %%
Particpants

# %%
Particpants.append("Dwayne")
Particpants

# %%
Particpants.extend(['George', 'Catehrine'])
Particpants

# %%
len(Particpants)

# %%
Particpants.index("George")

# %%
NewComers = ['Joshua', 'Brittany']

# %%
Bigger_List = [Particpants, NewComers]
Bigger_List

# %%
Particpants.sort()
Particpants

# %%
Particpants.sort(reverse=True)
Particpants

# %%
x = (40, 41, 42)
x

# %%
y = 50, 51, 52
y
